# %% [markdown]
# # Heart Disease prediction  using pycaret

# %% [markdown]
# problem statement :We have a data which classified if patients have heart disease or not according to features in it. We will try to use this data to create a model which tries predict if a patient has this disease or not. We will use logistic regression (classification) algorithm

# %% [markdown]
# Data contains;
# •	age - age in years
# •	sex - (1 = male; 0 = female)
# •	cp - chest pain type
# •	trestbps - resting blood pressure (in mm Hg on admission to the hospital)
# •	chol - serum cholestoral in mg/dl
# •	fbs - (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# •	restecg - resting electrocardiographic results
# •	thalach - maximum heart rate achieved
# •	exang - exercise induced angina (1 = yes; 0 = no)
# •	oldpeak - ST depression induced by exercise relative to rest
# •	slope - the slope of the peak exercise ST segment
# •	ca - number of major vessels (0-3) colored by flourosopy
# •	thal - 3 = normal; 6 = fixed defect; 7 = reversable defect
# •	target - have disease or not (1=yes, 0=no)

# %% [markdown]
# Requirements
#
# pycaret==2.1
# numpy
# pandas

# %%
import numpy as np #first install numpy the import as numpy 
import pandas as  pd #first install pandas import as pandas

# %%
dataset = pd.read_csv("heart.csv") #set the data in dataset

# %%
dataset  #dataset
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
from pycaret.classification import *   #classification using pycaret

# %%
clf1 = setup(data = dataset, target = 'target') #set the target
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_3ef70ee4_f599_11ea_8e83_3ca82aba1357" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3ef70ee4_f599_11ea_8e83_3ca82aba1357level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3ef70ee4_f599_11ea_8e83_3ca82aba1357row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_3ef70ee4_f599_11ea_8e83_3ca82aba1357row0_col1" class="data row0 col1" >7764</td>
#             </tr>
#             <tr>
#                         <th id="T_3ef70ee4_f599_11ea_8e83_3ca82aba1357level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3ef70ee4_f599_11ea_8e83_3ca82aba1357row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
logisticregression= create_model('lr')  #
# Out:
# <style  type="text/css" >
# #T_44559abd_f599_11ea_8bca_3ca82aba1357row10_col0,#T_44559abd_f599_11ea_8bca_3ca82aba1357row10_col1,#T_44559abd_f599_11ea_8bca_3ca82aba1357row10_col2,#T_44559abd_f599_11ea_8bca_3ca82aba1357row10_col3,#T_44559abd_f599_11ea_8bca_3ca82aba1357row10_col4,#T_44559abd_f599_11ea_8bca_3ca82aba1357row10_col5,#T_44559abd_f599_11ea_8bca_3ca82aba1357row10_col6{
#             background:  yellow;
#         }</style><table id="T_44559abd_f599_11ea_8bca_3ca82aba1357" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
predictions = predict_model(logiticregression,dataset)  #prediction

# %%
predictions
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target Label   Score
# 0        0   0     1       1     1  0.6408
# ...

# %%
plot_model(logiticregression)

# %%
predictions.head() #prediction head
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target Label   Score
# 0   0     1       1     1  0.6408
# 1   0     2       1     1  0.9093
# 2   0     2       1     1  0.9808
# 3   0     2       1     1  0.9732
# 4   0     2       1     1  0.8864

# %%
predictions.to_csv('prediction.csv') #save the

# %%
evaluate_model(estimator=logisticregression)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-62118ec66c89> in <module>
# ----> 1 evaluate_model(estimator=logisticregression)
#
# NameError: name 'logisticregression' is not defined

# %%
save_model(logiticregression,'heartdiseae1235')  #save model
# Out:
# Transformation Pipeline and Model Succesfully Saved
